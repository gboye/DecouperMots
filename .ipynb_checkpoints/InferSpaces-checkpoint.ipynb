# %%
import codecs,re,math,time
import numpy as np
import itertools as it

# %% [markdown]
# # Lire le texte

# %%
with codecs.open("/Users/gilles/ownCloud/Cours/Bordeaux/L3-Morphologie3/Balzac.txt","r",encoding="utf8") as input:
    texteComplet=" ".join([l.strip() for l in input.readlines()])

# %%
caracteresFiltres=re.escape(u" \n/()[]-:;,=°'_")
chunkStops=re.escape(u".?!«»")

# %%
texteFiltre=re.sub(ur"[%s]"%caracteresFiltres,"",texteComplet).lower()

# %%
chunksAll=re.split(ur"[%s0-9]+"%chunkStops,texteFiltre)

# %%
print len(chunksAll)
nbChunks=5000
chunks=chunksAll[:nbChunks]
# Out:
# 29967

# %% [markdown]
# # Extraire les Ngrams

# %%
def addNgrams(chunk,ngrams):
    lMaxNgram=min(25,len(chunk))
    for l in range(2,lMaxNgram+1):
        for i in range(len(chunk)+1-l):
            ngram=chunk[i:i+l]
            if not ngram in ngrams:
                ngrams[ngram]=0
            ngrams[ngram]+=1

# %%
ngrams={}
for chunk in chunks:
    addNgrams(chunk,ngrams)

# %%
words=sorted(ngrams, key=ngrams.get,reverse=True)

# %%
words
# Out:
# [u'es',
#  u'le',
#  u'en',
#  u'de',
#  u're',
#  u'nt',
#  u'ai',
#  u'on',
#  u'ou',
#  u'se',
#  u'it',
#  u'el',
#  u'la',
#  u'te',
#  u'ne',
#  u'er',
#  u'ur',
#  u'qu',
#  u'an',
#  u'eu',
#  u'et',
#  u'is',
#  u'ie',
#  u'me',
#  u'ent',
#  u'il',
#  u'in',
#  u'sa',
#  u'em',
#  u'ar',
#  u'ue',
#  u'un',
#  u'ns',
#  u'ed',
#  u'll',
#  u'ce',
#  u'ss',
#  u'ra',
#  u'ta',
#  u'les',
#  u'us',
#  u'ui',
#  u'co',
#  u'pa',
#  u'tr',
#  u'ec',
#  u'ti',
#  u'ait',
#  u'que',
#  u'ma',
#  u'lle',
#  u'so',
#  u'ep',
#  u'si',
#  u'au',
#  u'nd',
#  u'ri',
#  u'ir',
#  u'oi',
#  u'sd',
#  u'st',
#  u'ro',
#  u'nc',
#  u'des',
#  u'ut',
#  u'om',
#  u'as',
#  u'av',
#  u've',
#  u'pr',
#  u'po',
#  u'da',
#  u'ev',
#  u'ede',
#  u'rs',
#  u'mo',
#  u'ant',
#  u'tl',
#  u'ch',
#  u'al',
#  u'na',
#  u'une',
#  u'sp',
#  u'li',
#  u'ell',
#  u'our',
#  u'eur',
#  u'td',
#  u'elle',
#  u'at',
#  u'ts',
#  u'or',
#  u'ee',
#  u'ea',
#  u'lu',
#  u'pe',
#  u'rd',
#  u'vo',
#  u'sl',
#  u'am',
#  u'va',
#  u'to',
#  u'ien',
#  u'di',
#  u'du',
#  u'rt',
#  u'ap',
#  u'par',
#  u'men',
#  u'ais',
#  u'tre',
#  u'sde',
#  u'tt',
#  u'ux',
#  u'vi',
#  u'qui',
#  u'ac',
#  u'res',
#  u'ef',
#  u'su',
#  u'rl',
#  u'son',
#  u'pl',
#  u'ill',
#  u'ment',
#  u'mm',
#  u'ese',
#  u'io',
#  u'tu',
#  u'sc',
#  u'mi',
#  u'nn',
#  u't\xe9',
#  u'ei',
#  u'ela',
#  u'ge',
#  u'r\xe9',
#  u'ess',
#  u'he',
#  u'uel',
#  u'\xe9t',
#  u'sse',
#  u'lo',
#  u'del',
#  u'ni',
#  u'do',
#  u'mme',
#  u'nte',
#  u'tp',
#  u'tai',
#  u'ans',
#  u'fa',
#  u'je',
#  u'no',
#  u'quel',
#  u'est',
#  u'ad',
#  u'\xe8r',
#  u'\xe8re',
#  u'ion',
#  u'ous',
#  u'bl',
#  u'fi',
#  u'\xe9e',
#  u'ses',
#  u'ons',
#  u'esp',
#  u'ine',
#  u'esd',
#  u'eq',
#  u'equ',
#  u'eme',
#  u'ele',
#  u'tou',
#  u'tle',
#  u'esa',
#  u'ont',
#  u'ire',
#  u'dan',
#  u'sq',
#  u'squ',
#  u'd\xe9',
#  u'ure',
#  u'ten',
#  u'uv',
#  u'pou',
#  u'ren',
#  u'im',
#  u'tde',
#  u'mp',
#  u'vai',
#  u'com',
#  u'con',
#  u'eux',
#  u'ab',
#  u'onn',
#  u'ha',
#  u'omm',
#  u'pas',
#  u'nde',
#  u'mai',
#  u's\xe9',
#  u'urs',
#  u'sle',
#  u'ag',
#  u'emen',
#  u'ille',
#  u'nes',
#  u'end',
#  u'ement',
#  u'ca',
#  u'eso',
#  u'che',
#  u'ci',
#  u'sen',
#  u'eco',
#  u'eet',
#  u'ient',
#  u'rai',
#  u'ul',
#  u'id',
#  u'sm',
#  u'ces',
#  u'out',
#  u'ntl',
#  u'tte',
#  u'omme',
#  u'\xe9s',
#  u'ond',
#  u'nce',
#  u'ett',
#  u'ig',
#  u'tes',
#  u'eun',
#  u'ieu',
#  u'ic',
#  u'dans',
#  u'ia',
#  u'aie',
#  u'ru',
#  u'ema',
#  u'pour',
#  u'fo',
#  u'ssa',
#  u'ol',
#  u'ava',
#  u'rc',
#  u'ouv',
#  u'\xe9c',
#  u'tio',
#  u'tion',
#  u'rle',
#  u'af',
#  u'eau',
#  u'nts',
#  u'san',
#  u'ser',
#  u'aien',
#  u'aient',
#  u'rde',
#  u'dem',
#  u'ise',
#  u'mon',
#  u'oir',
#  u'epa',
#  u'bo',
#  u'ite',
#  u'cr',
#  u'ble',
#  u'ng',
#  u'enc',
#  u'dec',
#  u'ave',
#  u'ain',
#  u'\xe9ta',
#  u'tc',
#  u'iss',
#  u'ens',
#  u'ois',
#  u'dela',
#  u'ssi',
#  u'ntr',
#  u'leu',
#  u'up',
#  u'lui',
#  u'esc',
#  u'plu',
#  u'n\xe9',
#  u'ntd',
#  u'ere',
#  u'sai',
#  u'mb',
#  u'vou',
#  u'lus',
#  u'\xeat',
#  u'lai',
#  u'iv',
#  u'\xe9p',
#  u'cha',
#  u'int',
#  u'ile',
#  u'nta',
#  u'uil',
#  u'ati',
#  u'eg',
#  u'esde',
#  u'vr',
#  u'set',
#  u'vait',
#  u'voi',
#  u'gu',
#  u'np',
#  u'ece',
#  u'mais',
#  u'ort',
#  u'os',
#  u'don',
#  u'ers',
#  u'gi',
#  u'tait',
#  u'uis',
#  u'nne',
#  u'ho',
#  u'rm',
#  u'\xe9d',
#  u'ud',
#  u'rr',
#  u'plus',
#  u'\xe9r',
#  u'uc',
#  u'bi',
#  u'tun',
#  u'ette',
#  u'avai',
#  u'fe',
#  u'emo',
#  u'ej',
#  u'jo',
#  u'sur',
#  u'air',
#  u'ard',
#  u'cet',
#  u'lem',
#  u'um',
#  u'ua',
#  u'dun',
#  u'tla',
#  u'eune',
#  u'len',
#  u'lep',
#  u'ez',
#  u'tqu',
#  u'tq',
#  u'and',
#  u'cu',
#  u'\xe9tai',
#  u'ass',
#  u'eb',
#  u'ier',
#  u'ls',
#  u'eil',
#  u'use',
#  u'mes',
#  u'leur',
#  u'l\xe9',
#  u'lles',
#  u'gr',
#  u'comm',
#  u'iq',
#  u'ga',
#  u'iqu',
#  u'edes',
#  u'fai',
#  u'led',
#  u'pro',
#  u'anc',
#  u'ter',
#  u'sf',
#  u'tra',
#  u'url',
#  u'ba',
#  u't\xe0',
#  u'e\xe0',
#  u'tout',
#  u'\xe0l',
#  u'dr',
#  u'ran',
#  u'ene',
#  u'sou',
#  u'\xe9l',
#  u'sque',
#  u'sles',
#  u'ita',
#  u'red',
#  u'nti',
#  u'rel',
#  u'lie',
#  u'ins',
#  u'cou',
#  u'sr',
#  u'nf',
#  u'ues',
#  u'vie',
#  u'pi',
#  u'tro',
#  u'ena',
#  u'dit',
#  u'itl',
#  u'tel',
#  u'lap',
#  u'esse',
#  u'ein',
#  u'eurs',
#  u'ip',
#  u'spa',
#  u'tpa',
#  u'ntle',
#  u'nsl',
#  u'evo',
#  u'nai',
#  u'epr',
#  u'rent',
#  u'ct',
#  u'ente',
#  u'isa',
#  u'nco',
#  u'aut',
#  u'vous',
#  u'eque',
#  u'evi',
#  u'sem',
#  u'ute',
#  u'art',
#  u'onc',
#  u'dev',
#  u'nsi',
#  u'moi',
#  u'rie',
#  u'pri',
#  u'pp',
#  u'pre',
#  u'rem',
#  u'cett',
#  u'cette',
#  u'jou',
#  u'it\xe9',
#  u'equi',
#  u'br',
#  u'rn',
#  u'nse',
#  u'ven',
#  u'ste',
#  u'gn',
#  u'lac',
#  u'comme',
#  u'rou',
#  u'ver',
#  u'tles',
#  u'ents',
#  u'jeu',
#  u'itd',
#  u'aire',
#  u'een',
#  u'per',
#  u'lec',
#  u'aux',
#  u'ils',
#  u'nev',
#  u'age',
#  u'lam',
#  u'ist',
#  u'ff',
#  u'ot',
#  u'tem',
#  u'itp',
#  u'cl',
#  u'ique',
#  u'ansl',
#  u'ex',
#  u'rla',
#  u'i\xe8',
#  u'lan',
#  u'rit',
#  u'era',
#  u'sla',
#  u'sav',
#  u'fr',
#  u'ret',
#  u'sil',
#  u'onne',
#  u'ale',
#  u'etl',
#  u'til',
#  u'\xe9tait',
#  u'urd',
#  u'epo',
#  u'quil',
#  u'jeun',
#  u'jeune',
#  u'uss',
#  u'qua',
#  u'avait',
#  u'sco',
#  u'esm',
#  u'esqu',
#  u'nep',
#  u'epe',
#  u'esq',
#  u'its',
#  u'man',
#  u'ler',
#  u'vec',
#  u'tm',
#  u'sent',
#  u'esi',
#  u'sel',
#  u'lar',
#  u'avec',
#  u'dansl',
#  u'voir',
#  u'epar',
#  u'abl',
#  u'etd',
#  u'run',
#  u'itu',
#  u'ets',
#  u'lav',
#  u'pu',
#  u'ree',
#  u'esl',
#  u'tin',
#  u'mil',
#  u'etr',
#  u'ques',
#  u'ntde',
#  u'nm',
#  u'rep',
#  u'rv',
#  u'onde',
#  u'rte',
#  u'elles',
#  u'nu',
#  u'ari',
#  u'm\xe9',
#  u'lla',
#  u'nv',
#  u'sie',
#  u'ama',
#  u'sn',
#  u'be',
#  u'dep',
#  u'der',
#  u'edu',
#  u'omp',
#  u'entd',
#  u'atio',
#  u'uve',
#  u'ation',
#  u'ntre',
#  u'oc',
#  u'deu',
#  u'if',
#  u'tan',
#  u'ude',
#  u'iti',
#  u'rp',
#  u'sv',
#  u'nda',
#  u'eson',
#  u'eles',
#  u'eva',
#  u'eus',
#  u'able',
#  u'ntp',
#  u'uell',
#  u'esu',
#  u'dece',
#  u'sso',
#  u'lon',
#  u'eto',
#  u'rait',
#  u'sb',
#  u'uelle',
#  u'tse',
#  u'mar',
#  u'\xe9es',
#  u'rqu',
#  u'rq',
#  u'r\xe8',
#  u'ence',
#  u'enti',
#  u'aus',
#  u'\xeatre',
#  u'\xeatr',
#  u'ech',
#  u'eo',
#  u'mad',
#  u'eh',
#  u'laf',
#  u'vra',
#  u'roi',
#  u'nou',
#  u'ris',
#  u'sti',
#  u'erl',
#  u'ner',
#  u'arl',
#  u'ions',
#  u'ura',
#  u'ndi',
#  u'entl',
#  u'\xe0la',
#  u'pen',
#  u'rec',
#  u'lea',
#  u'e\xe9',
#  u'lesp',
#  u'nl',
#  u'ind',
#  u'ide',
#  u'tque',
#  u'avo',
#  u'dre',
#  u'\xe9m',
#  u'bie',
#  u'let',
#  u'ante',
#  u'sin',
#  u'ade',
#  u'eje',
#  u'ob',
#  u'jour',
#  u'squi',
#  u'fil',
#  u'rti',
#  u'nef',
#  u'isi',
#  u'erd',
#  u'ndr',
#  u'lev',
#  u'ned',
#  u'bien',
#  u'oute',
#  u'reu',
#  u'app',
#  u'ance',
#  u'ress',
#  u'sdes',
#  u'aitp',
#  u'rles',
#  u'ja',
#  u'ours',
#  u'sma',
#  u'ule',
#  u'esf',
#  u'quell',
#  u'issa',
#  u'parl',
#  u'gar',
#  u'ya',
#  u'eure',
#  u'euse',
#  u'lat',
#  u'sun',
#  u'quelle',
#  u'tau',
#  u'sau',
#  u'ouve',
#  u'i\xe8re',
#  u'i\xe8r',
#  u'rse',
#  u'ame',
#  u'rg',
#  u'econ',
#  u'nten',
#  u'sj',
#  u'sdu',
#  u'deso',
#  u'fu',
#  u'oin',
#  u'tpas',
#  u'elu',
#  u'aitd',
#  u'sait',
#  u'oe',
#  u'ug',
#  u'heu',
#  u'aitl',
#  u'det',
#  u'op',
#  u'emb',
#  u'nq',
#  u'lqu',
#  u'rede',
#  u'lq',
#  u'gin',
#  u'sdel',
#  u'heur',
#  u'ime',
#  u'epl',
#  u'pla',
#  u'ted',
#  u'spar',
#  u'cc',
#  u'deux',
#  u'eav',
#  u'emi',
#  u'emp',
#  u'entr',
#  u'ecom',
#  u'eda',
#  u'erc',
#  u'tune',
#  u'dune',
#  u'ign',
#  u'emm',
#  u'spo',
#  u'emme',
#  u'tdes',
#  u'efi',
#  u'\xe9g',
#  u'desa',
#  u'nr',
#  u'den',
#  u'hom',
#  u'oy',
#  u'enta',
#  u'str',
#  u'lese',
#  u'comp',
#  u'rce',
#  u'por',
#  u'edel',
#  u'fill',
#  u'nqu',
#  u'fille',
#  u'nsle',
#  u's\xe0',
#  u'dis',
#  u'nsd',
#  u'ili',
#  u'ye',
#  u'nen',
#  u'eta',
#  u'homm',
#  u'aiss',
#  u'\xe9de',
#  u'eill',
#  u'\xe0s',
#  u'rouv',
#  u'edo',
#  u'lee',
#  u'eli',
#  u'urle',
#  u'selle',
#  u'sell',
#  u'eve',
#  u'ieur',
#  u'\xe8s',
#  u'dese',
#  u'ami',
#  u'inc',
#  u'dam',
#  u'eno',
#  u'dema',
#  u'spr',
#  u'esr',
#  u'ert',
#  u'homme',
#  u'lque',
#  u'unes',
#  u'illa',
#  u'for',
#  u'epou',
#  u'nel',
#  u'tant',
#  u'nna',
#  u'eset',
#  u'lede',
#  u'port',
#  u'cie',
#  u'ate',
#  u'peu',
#  u'apr',
#  u'ada',
#  u'hi',
#  u'bon',
#  u'cel',
#  u'ach',
#  u'erv',
#  u'gard',
#  u'xp',
#  u'leurs',
#  u'spe',
#  u't\xeat',
#  u't\xea',
#  u'elq',
#  u'aits',
#  u'fem',
#  u'elqu',
#  u'nem',
#  u'sans',
#  u'las',
#  u'sg',
#  u'aite',
#  u'ega',
#  u'evr',
#  u'ila',
#  u'part',
#  u'sta',
#  u'reg',
#  u'femm',
#  u'sed',
#  u'femme',
#  u'van',
#  u'ona',
#  u'oul',
#  u'onsi',
#  u'etou',
#  u'tce',
#  u'sce',
#  u'\xe9n',
#  u'def',
#  u'enf',
#  u'onna',
#  u'eses',
#  u'lled',
#  u'ron',
#  u'surl',
#  u'elque',
#  u'edi',
#  u'avi',
#  u'p\xe9',
#  u'tsa',
#  u'net',
#  u'tda',
#  u'ib',
#  u'iso',
#  u'gra',
#  u'i\xe9',
#  u'car',
#  u'mbl',
#  u'onp',
#  u'tell',
#  u'elui',
#  u'efo',
#  u'utr',
#  u'th',
#  u'rso',
#  u'uelqu',
#  u'uelq',
#  u'rea',
#  u'usa',
#  u'uva',
#  u'eurd',
#  u'oeu',
#  u'ansle',
#  u'cor',
#  u'uelque',
#  u'ued',
#  u'tend',
#  u'ntles',
#  u'quelq',
#  u'quelqu',
#  u'ndre',
#  u'ssan',
#  u'itle',
#  u'pr\xe9',
#  u'quelque',
#  u'lel',
#  u'sant',
#  u'\xe0c',
#  u'r\xe8s',
#  u'ments',
#  u'antl',
#  u'eti',
#  u'unef',
#  u'lin',
#  u'aum',
#  u'pass',
#  u'med',
#  u'uele',
#  u'demo',
#  u'urde',
#  u'ete',
#  u'lesd',
#  u'avoi',
#  u'gine',
#  u'sio',
#  u'tres',
#  u'\xe9po',
#  u'evra',
#  u'all',
#  u'rav',
#  u'vin',
#  u'sit',
#  u'cont',
#  u'embl',
#  u'are',
#  u'inev',
#  u'asse',
#  u'tet',
#  u'tur',
#  u'ara',
#  u'bla',
#  u'gen',
#  u'eut',
#  u'g\xe9',
#  u'ub',
#  u'sion',
#  u'telle',
#  u'ira',
#  u'dansle',
#  u'squel',
#  u'egar',
#  u'efa',
#  u'quele',
#  u'att',
#  u'esco',
#  u'sieu',
#  u'donn',
#  u'ced',
#  u'rda',
#  u'trou',
#  u'tso',
#  u'lit',
#  u'sieur',
#  u'nge',
#  u'endr',
#  u'nevr',
#  u'lab',
#  u'sre',
#  u'ust',
#  u'mou',
#  u'tf',
#  u'o\xf9',
#  u'ieux',
#  u'uta',
#  u'r\xe9s',
#  u'lau',
#  u'ginev',
#  u'ginevr',
#  u'inevr',
#  u'entle',
#  u'conn',
#  u'omb',
#  u'lais',
#  u'pos',
#  u'amo',
#  u'uj',
#  u'uid',
#  u'aine',
#  u'vre',
#  u'fon',
#  u'espa',
#  u'egard',
#  u'ussi',
#  u'ded',
#  u'aco',
#  u'equel',
#  u'dame',
#  u'ants',
#  u'uit',
#  u'sec',
#  u'entp',
#  u'ntqu',
#  u'nevra',
#  u'v\xe9',
#  u'ong',
#  u'ali',
#  u'ginevra',
#  u'ntq',
#  u'afi',
#  u'inevra',
#  u'ail',
#  u'ang',
#  u'tal',
#  u'rsa',
#  u'ntu',
#  u'ntc',
#  u'rer',
#  u'usd',
#  u'oup',
#  u'tit',
#  u'cri',
#  u'tn',
#  u'etde',
#  u'deson',
#  u'sto',
#  u'aj',
#  u'amai',
#  u'spl',
#  u'rega',
#  u'pei',
#  u'lh',
#  u'ouva',
#  u'semb',
#  u'nh',
#  u'\xe9ri',
#  u'eca',
#  ...]

# %% [markdown]
# # Calculer les coûts par Ngram

# %%
from math import log

# Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
#words = open("words-by-frequency.txt").read().split()
wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
maxword = max(len(x) for x in words)

def infer_spaces(s):
    """Uses dynamic programming to infer the location of spaces in a string
    without spaces."""

    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
        candidates = enumerate(reversed(cost[max(0, i-maxword):i]))
        return min((c + wordcost.get(s[i-k-1:i], 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
        c,k = best_match(i)
        cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
        c,k = best_match(i)
        assert c == cost[i]
        out.append(s[i-k:i])
        i -= k

    return " ".join(reversed(out))

# %%
for chunk in chunks[:50]:
    print infer_spaces(chunk)
    print
# Out:
# lamaisonduchatquipelote lebaldesceauxlabourselave ndettamadamefirmianiunedo ublefamillelapaixduména gelafaussemaitresseétuded efemmealbertsavaruspari sveuveandrehoussiauxédite urhébertetciesuccesseurs
#
# rueperronet
#
# honorédebalzacbalza cnaquitàtoursle
#
# mai
#
# le jourdelafêtedesainthonoré dontonluidonnalenomquipa rutbiensonnantetdebonaugu re
#
# lepetithonorénefutpasune nfantprodigeilnannonçapas prématurémentquilferaitl acomédiehumaine
#
# cétaitungarçonfraisvermei lbienportantjoueurauxyeux brillantsetdouxmaisquerie nnedistinguaitdesautresdu moi nsàdesregardspeuattentifs
#
# aseptansausortirdunextern atdetoursonlemitaucollég edevendômetenupardesorat oriensoùilpassapourun élèvetrèsmédiocre
#
# lapremièrepartiede louislambertcontientsurce tempsdelaviedebalzacd ecurieuxrenseignements
#
# dédoublantsapersonnalitéi lsypeintcommeunanciencond iscipledelouislamberttant ôtenparlantensonnomett antôtprêtantsespropressen timentsàcepersonnageimagi nairemaispourtanttrèsréel puisquilestunesortedobje ctifdelâmemêmedelécrivain
#
# balzacsouffritprodigieus ementdanscecollégedevend ômeoùsanaturerêveuseétai tmeurtrieàchaqueinsta ntparunerègleinflexible
#
# ilnégligeaitdefairesesdev oirsmaisfavorisépa rlacomplicitétacitedunrép étiteurdemathématiquese nmêmetempsbibliothéca ireetoccupédequelqueouv ragetranscendentalilnepr enaitpassaleçonetempo rtaitleslivresquilvoulait
#
# toutsontempssepassait àlireencachette
#
# aussifutilbientôtlélè velepluspunidesaclasse
#
# lespensumslesretenuesabso rbèrentbientôtletempsdesr écréationsàcertaines naturesdécoliersleschâ timentsinspirentunesorted erébellionstoïqueetilsop posentauxprofesseursexas péréslamêmeimpassibi litédédaigneusequelesg uerrierssauvagescaptifsa uxennemisquilestorturent
#
# nilecachotnilaprivat iondalimentsnilaférulenep arviennentàleurarracherla moindreplaintecesontal orsentrelemaîtreetlélèved eslutteshorriblesinconnue sdesparentsoùlaconstance desmartyrsetlhabiletédesb ourreauxsetrouventégalées
